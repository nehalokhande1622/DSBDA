# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import stats

# %%
df=pd.read_excel("C:/Users/LENOVO/Desktop/students.csv.xlsx")

# %%
df
# Out:
#     math score  reading score  writing score  club join year  placement offer  \
# 0           70           78.0             80            2021                2
# 1           73           62.0             70            2022                2
# 2           75           60.0             79            2022                1
# 3           80           70.0             61            2022                3
# 4           60           67.0             79            2024                3
# 5           80            NaN             71            2020                1
# 6           62           67.0             79            2023                2
# 7           63           69.0             74            2018                2
# 8           62           71.0             71            2018                3
# 9           76           73.0             73            2024                2
# 10          65           66.0             73            2019                3
# 11          70           75.0             79            2020                1
# 12          75           67.0             77            2024                2
# 13          80           61.0             65            2019                3
# 14          62           66.0             69            2019                1
# 15          74           80.0             79            2018                1
# 16          72           79.0             77            2022                3
# 17          70           62.0             78            2024                1
# 18          72           70.0             74            2023                2
# 19          64           68.0             71            2019                1
# 20          64           62.0             69            2018                3
# 21          68           63.0             65            2023                3
# 22          60           67.0             75            2024                3
# 23          73           65.0             76            2021                2
# 24          72           79.0             63            2018                3
# 25          76           64.0             72            2021                1
# 26          75           79.0             62            2019                1
# 27          79           60.0             66            2019                2
# 28          80           74.0             73            2022                2
#
#     gender
# 0     male
# 1   female
# 2   female
# 3     male
# 4     male
# 5   female
# 6   female
# 7   female
# 8     male
# 9     male
# 10  female
# 11  female
# 12  female
# 13  female
# 14    male
# 15  female
# 16  female
# 17  female
# 18  female
# 19  female
# 20    male
# 21  female
# 22  female
# 23  female
# 24    male
# 25    male
# 26  female
# 27  female
# 28  female

# %%
df.isnull()
# Out:
#     math score  reading score  writing score  club join year  placement offer  \
# 0        False          False          False           False            False
# 1        False          False          False           False            False
# 2        False          False          False           False            False
# 3        False          False          False           False            False
# 4        False          False          False           False            False
# 5        False           True          False           False            False
# 6        False          False          False           False            False
# 7        False          False          False           False            False
# 8        False          False          False           False            False
# 9        False          False          False           False            False
# 10       False          False          False           False            False
# 11       False          False          False           False            False
# 12       False          False          False           False            False
# 13       False          False          False           False            False
# 14       False          False          False           False            False
# 15       False          False          False           False            False
# 16       False          False          False           False            False
# 17       False          False          False           False            False
# 18       False          False          False           False            False
# 19       False          False          False           False            False
# 20       False          False          False           False            False
# 21       False          False          False           False            False
# 22       False          False          False           False            False
# 23       False          False          False           False            False
# 24       False          False          False           False            False
# 25       False          False          False           False            False
# 26       False          False          False           False            False
# 27       False          False          False           False            False
# 28       False          False          False           False            False
#
#     gender
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# 10   False
# 11   False
# 12   False
# 13   False
# 14   False
# 15   False
# 16   False
# 17   False
# 18   False
# 19   False
# 20   False
# 21   False
# 22   False
# 23   False
# 24   False
# 25   False
# 26   False
# 27   False
# 28   False

# %%
series = pd.isnull(df["reading score"])
df[series]
# Out:
#    math score  reading score  writing score  club join year  placement offer  \
# 5          80            NaN             71            2020                1
#
#    gender
# 5  female

# %%
df.notnull()
# Out:
#     math score  reading score  writing score  club join year  placement offer  \
# 0         True           True           True            True             True
# 1         True           True           True            True             True
# 2         True           True           True            True             True
# 3         True           True           True            True             True
# 4         True           True           True            True             True
# 5         True          False           True            True             True
# 6         True           True           True            True             True
# 7         True           True           True            True             True
# 8         True           True           True            True             True
# 9         True           True           True            True             True
# 10        True           True           True            True             True
# 11        True           True           True            True             True
# 12        True           True           True            True             True
# 13        True           True           True            True             True
# 14        True           True           True            True             True
# 15        True           True           True            True             True
# 16        True           True           True            True             True
# 17        True           True           True            True             True
# 18        True           True           True            True             True
# 19        True           True           True            True             True
# 20        True           True           True            True             True
# 21        True           True           True            True             True
# 22        True           True           True            True             True
# 23        True           True           True            True             True
# 24        True           True           True            True             True
# 25        True           True           True            True             True
# 26        True           True           True            True             True
# 27        True           True           True            True             True
# 28        True           True           True            True             True
#
#     gender
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True

# %%
seseries = pd.notnull(df["reading score"])
df[series]
# Out:
#    math score  reading score  writing score  club join year  placement offer  \
# 5          80            NaN             71            2020                1
#
#    gender
# 5  female

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder ()
df['gender'] = le.fit_transform(df['gender'])
newdf=df
df
# Out:
#     math score  reading score  writing score  club join year  placement offer  \
# 0           70           78.0             80            2021                2
# 1           73           62.0             70            2022                2
# 2           75           60.0             79            2022                1
# 3           80           70.0             61            2022                3
# 4           60           67.0             79            2024                3
# 5           80            NaN             71            2020                1
# 6           62           67.0             79            2023                2
# 7           63           69.0             74            2018                2
# 8           62           71.0             71            2018                3
# 9           76           73.0             73            2024                2
# 10          65           66.0             73            2019                3
# 11          70           75.0             79            2020                1
# 12          75           67.0             77            2024                2
# 13          80           61.0             65            2019                3
# 14          62           66.0             69            2019                1
# 15          74           80.0             79            2018                1
# 16          72           79.0             77            2022                3
# 17          70           62.0             78            2024                1
# 18          72           70.0             74            2023                2
# 19          64           68.0             71            2019                1
# 20          64           62.0             69            2018                3
# 21          68           63.0             65            2023                3
# 22          60           67.0             75            2024                3
# 23          73           65.0             76            2021                2
# 24          72           79.0             63            2018                3
# 25          76           64.0             72            2021                1
# 26          75           79.0             62            2019                1
# 27          79           60.0             66            2019                2
# 28          80           74.0             73            2022                2
#
#     gender
# 0        1
# 1        0
# 2        0
# 3        1
# 4        1
# 5        0
# 6        0
# 7        0
# 8        1
# 9        1
# 10       0
# 11       0
# 12       0
# 13       0
# 14       1
# 15       0
# 16       0
# 17       0
# 18       0
# 19       0
# 20       1
# 21       0
# 22       0
# 23       0
# 24       1
# 25       1
# 26       0
# 27       0
# 28       0

# %%
df['gender'].replace({1: "male", 0: "female"}, inplace=True)
df
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_64548\1953152719.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['gender'].replace({1: "male", 0: "female"}, inplace=True)
#     math score  reading score  writing score  club join year  placement offer  \
# 0           70           78.0             80            2021                2
# 1           73           62.0             70            2022                2
# 2           75           60.0             79            2022                1
# 3           80           70.0             61            2022                3
# 4           60           67.0             79            2024                3
# 5           80            NaN             71            2020                1
# 6           62           67.0             79            2023                2
# 7           63           69.0             74            2018                2
# 8           62           71.0             71            2018                3
# 9           76           73.0             73            2024                2
# 10          65           66.0             73            2019                3
# 11          70           75.0             79            2020                1
# 12          75           67.0             77            2024                2
# 13          80           61.0             65            2019                3
# 14          62           66.0             69            2019                1
# 15          74           80.0             79            2018                1
# 16          72           79.0             77            2022                3
# 17          70           62.0             78            2024                1
# 18          72           70.0             74            2023                2
# 19          64           68.0             71            2019                1
# 20          64           62.0             69            2018                3
# 21          68           63.0             65            2023                3
# 22          60           67.0             75            2024                3
# 23          73           65.0             76            2021                2
# 24          72           79.0             63            2018                3
# 25          76           64.0             72            2021                1
# 26          75           79.0             62            2019                1
# 27          79           60.0             66            2019                2
# 28          80           74.0             73            2022                2
#
#     gender
# 0     male
# 1   female
# 2   female
# 3     male
# 4     male
# 5   female
# 6   female
# 7   female
# 8     male
# 9     male
# 10  female
# 11  female
# 12  female
# 13  female
# 14    male
# 15  female
# 16  female
# 17  female
# 18  female
# 19  female
# 20    male
# 21  female
# 22  female
# 23  female
# 24    male
# 25    male
# 26  female
# 27  female
# 28  female

# %%
ndf=df
ndf.fillna(0)
# Out:
#     math score  reading score  writing score  club join year  placement offer  \
# 0           70           78.0             80            2021                2
# 1           73           62.0             70            2022                2
# 2           75           60.0             79            2022                1
# 3           80           70.0             61            2022                3
# 4           60           67.0             79            2024                3
# 5           80            0.0             71            2020                1
# 6           62           67.0             79            2023                2
# 7           63           69.0             74            2018                2
# 8           62           71.0             71            2018                3
# 9           76           73.0             73            2024                2
# 10          65           66.0             73            2019                3
# 11          70           75.0             79            2020                1
# 12          75           67.0             77            2024                2
# 13          80           61.0             65            2019                3
# 14          62           66.0             69            2019                1
# 15          74           80.0             79            2018                1
# 16          72           79.0             77            2022                3
# 17          70           62.0             78            2024                1
# 18          72           70.0             74            2023                2
# 19          64           68.0             71            2019                1
# 20          64           62.0             69            2018                3
# 21          68           63.0             65            2023                3
# 22          60           67.0             75            2024                3
# 23          73           65.0             76            2021                2
# 24          72           79.0             63            2018                3
# 25          76           64.0             72            2021                1
# 26          75           79.0             62            2019                1
# 27          79           60.0             66            2019                2
# 28          80           74.0             73            2022                2
#
#     gender
# 0     male
# 1   female
# 2   female
# 3     male
# 4     male
# 5   female
# 6   female
# 7   female
# 8     male
# 9     male
# 10  female
# 11  female
# 12  female
# 13  female
# 14    male
# 15  female
# 16  female
# 17  female
# 18  female
# 19  female
# 20    male
# 21  female
# 22  female
# 23  female
# 24    male
# 25    male
# 26  female
# 27  female
# 28  female

# %%
m_v=df['reading score'].mean()
df['reading score'].fillna(value=m_v, inplace=True)
df
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_64548\800877498.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['reading score'].fillna(value=m_v, inplace=True)
#     math score  reading score  writing score  club join year  placement offer  \
# 0           70      78.000000             80            2021                2
# 1           73      62.000000             70            2022                2
# 2           75      60.000000             79            2022                1
# 3           80      70.000000             61            2022                3
# 4           60      67.000000             79            2024                3
# 5           80      68.714286             71            2020                1
# 6           62      67.000000             79            2023                2
# 7           63      69.000000             74            2018                2
# 8           62      71.000000             71            2018                3
# 9           76      73.000000             73            2024                2
# 10          65      66.000000             73            2019                3
# 11          70      75.000000             79            2020                1
# 12          75      67.000000             77            2024                2
# 13          80      61.000000             65            2019                3
# 14          62      66.000000             69            2019                1
# 15          74      80.000000             79            2018                1
# 16          72      79.000000             77            2022                3
# 17          70      62.000000             78            2024                1
# 18          72      70.000000             74            2023                2
# 19          64      68.000000             71            2019                1
# 20          64      62.000000             69            2018                3
# 21          68      63.000000             65            2023                3
# 22          60      67.000000             75            2024                3
# 23          73      65.000000             76            2021                2
# 24          72      79.000000             63            2018                3
# 25          76      64.000000             72            2021                1
# 26          75      79.000000             62            2019                1
# 27          79      60.000000             66            2019                2
# 28          80      74.000000             73            2022                2
#
#     gender
# 0     male
# 1   female
# 2   female
# 3     male
# 4     male
# 5   female
# 6   female
# 7   female
# 8     male
# 9     male
# 10  female
# 11  female
# 12  female
# 13  female
# 14    male
# 15  female
# 16  female
# 17  female
# 18  female
# 19  female
# 20    male
# 21  female
# 22  female
# 23  female
# 24    male
# 25    male
# 26  female
# 27  female
# 28  female

# %%
ndf.replace(to_replace = np.nan, value = -99)
# Out:
#     math score  reading score  writing score  club join year  placement offer  \
# 0           70      78.000000             80            2021                2
# 1           73      62.000000             70            2022                2
# 2           75      60.000000             79            2022                1
# 3           80      70.000000             61            2022                3
# 4           60      67.000000             79            2024                3
# 5           80      68.714286             71            2020                1
# 6           62      67.000000             79            2023                2
# 7           63      69.000000             74            2018                2
# 8           62      71.000000             71            2018                3
# 9           76      73.000000             73            2024                2
# 10          65      66.000000             73            2019                3
# 11          70      75.000000             79            2020                1
# 12          75      67.000000             77            2024                2
# 13          80      61.000000             65            2019                3
# 14          62      66.000000             69            2019                1
# 15          74      80.000000             79            2018                1
# 16          72      79.000000             77            2022                3
# 17          70      62.000000             78            2024                1
# 18          72      70.000000             74            2023                2
# 19          64      68.000000             71            2019                1
# 20          64      62.000000             69            2018                3
# 21          68      63.000000             65            2023                3
# 22          60      67.000000             75            2024                3
# 23          73      65.000000             76            2021                2
# 24          72      79.000000             63            2018                3
# 25          76      64.000000             72            2021                1
# 26          75      79.000000             62            2019                1
# 27          79      60.000000             66            2019                2
# 28          80      74.000000             73            2022                2
#
#     gender
# 0     male
# 1   female
# 2   female
# 3     male
# 4     male
# 5   female
# 6   female
# 7   female
# 8     male
# 9     male
# 10  female
# 11  female
# 12  female
# 13  female
# 14    male
# 15  female
# 16  female
# 17  female
# 18  female
# 19  female
# 20    male
# 21  female
# 22  female
# 23  female
# 24    male
# 25    male
# 26  female
# 27  female
# 28  female

# %%
ndf.dropna()
# Out:
#     math score  reading score  writing score  club join year  placement offer  \
# 0           70      78.000000             80            2021                2
# 1           73      62.000000             70            2022                2
# 2           75      60.000000             79            2022                1
# 3           80      70.000000             61            2022                3
# 4           60      67.000000             79            2024                3
# 5           80      68.714286             71            2020                1
# 6           62      67.000000             79            2023                2
# 7           63      69.000000             74            2018                2
# 8           62      71.000000             71            2018                3
# 9           76      73.000000             73            2024                2
# 10          65      66.000000             73            2019                3
# 11          70      75.000000             79            2020                1
# 12          75      67.000000             77            2024                2
# 13          80      61.000000             65            2019                3
# 14          62      66.000000             69            2019                1
# 15          74      80.000000             79            2018                1
# 16          72      79.000000             77            2022                3
# 17          70      62.000000             78            2024                1
# 18          72      70.000000             74            2023                2
# 19          64      68.000000             71            2019                1
# 20          64      62.000000             69            2018                3
# 21          68      63.000000             65            2023                3
# 22          60      67.000000             75            2024                3
# 23          73      65.000000             76            2021                2
# 24          72      79.000000             63            2018                3
# 25          76      64.000000             72            2021                1
# 26          75      79.000000             62            2019                1
# 27          79      60.000000             66            2019                2
# 28          80      74.000000             73            2022                2
#
#     gender
# 0     male
# 1   female
# 2   female
# 3     male
# 4     male
# 5   female
# 6   female
# 7   female
# 8     male
# 9     male
# 10  female
# 11  female
# 12  female
# 13  female
# 14    male
# 15  female
# 16  female
# 17  female
# 18  female
# 19  female
# 20    male
# 21  female
# 22  female
# 23  female
# 24    male
# 25    male
# 26  female
# 27  female
# 28  female

# %%
ndf.dropna(how = 'all')
# Out:
#     math score  reading score  writing score  club join year  placement offer  \
# 0           70      78.000000             80            2021                2
# 1           73      62.000000             70            2022                2
# 2           75      60.000000             79            2022                1
# 3           80      70.000000             61            2022                3
# 4           60      67.000000             79            2024                3
# 5           80      68.714286             71            2020                1
# 6           62      67.000000             79            2023                2
# 7           63      69.000000             74            2018                2
# 8           62      71.000000             71            2018                3
# 9           76      73.000000             73            2024                2
# 10          65      66.000000             73            2019                3
# 11          70      75.000000             79            2020                1
# 12          75      67.000000             77            2024                2
# 13          80      61.000000             65            2019                3
# 14          62      66.000000             69            2019                1
# 15          74      80.000000             79            2018                1
# 16          72      79.000000             77            2022                3
# 17          70      62.000000             78            2024                1
# 18          72      70.000000             74            2023                2
# 19          64      68.000000             71            2019                1
# 20          64      62.000000             69            2018                3
# 21          68      63.000000             65            2023                3
# 22          60      67.000000             75            2024                3
# 23          73      65.000000             76            2021                2
# 24          72      79.000000             63            2018                3
# 25          76      64.000000             72            2021                1
# 26          75      79.000000             62            2019                1
# 27          79      60.000000             66            2019                2
# 28          80      74.000000             73            2022                2
#
#     gender
# 0     male
# 1   female
# 2   female
# 3     male
# 4     male
# 5   female
# 6   female
# 7   female
# 8     male
# 9     male
# 10  female
# 11  female
# 12  female
# 13  female
# 14    male
# 15  female
# 16  female
# 17  female
# 18  female
# 19  female
# 20    male
# 21  female
# 22  female
# 23  female
# 24    male
# 25    male
# 26  female
# 27  female
# 28  female

# %%
ndf.dropna(axis = 1)
# Out:
#     math score  reading score  writing score  club join year  placement offer  \
# 0           70      78.000000             80            2021                2
# 1           73      62.000000             70            2022                2
# 2           75      60.000000             79            2022                1
# 3           80      70.000000             61            2022                3
# 4           60      67.000000             79            2024                3
# 5           80      68.714286             71            2020                1
# 6           62      67.000000             79            2023                2
# 7           63      69.000000             74            2018                2
# 8           62      71.000000             71            2018                3
# 9           76      73.000000             73            2024                2
# 10          65      66.000000             73            2019                3
# 11          70      75.000000             79            2020                1
# 12          75      67.000000             77            2024                2
# 13          80      61.000000             65            2019                3
# 14          62      66.000000             69            2019                1
# 15          74      80.000000             79            2018                1
# 16          72      79.000000             77            2022                3
# 17          70      62.000000             78            2024                1
# 18          72      70.000000             74            2023                2
# 19          64      68.000000             71            2019                1
# 20          64      62.000000             69            2018                3
# 21          68      63.000000             65            2023                3
# 22          60      67.000000             75            2024                3
# 23          73      65.000000             76            2021                2
# 24          72      79.000000             63            2018                3
# 25          76      64.000000             72            2021                1
# 26          75      79.000000             62            2019                1
# 27          79      60.000000             66            2019                2
# 28          80      74.000000             73            2022                2
#
#     gender
# 0     male
# 1   female
# 2   female
# 3     male
# 4     male
# 5   female
# 6   female
# 7   female
# 8     male
# 9     male
# 10  female
# 11  female
# 12  female
# 13  female
# 14    male
# 15  female
# 16  female
# 17  female
# 18  female
# 19  female
# 20    male
# 21  female
# 22  female
# 23  female
# 24    male
# 25    male
# 26  female
# 27  female
# 28  female

# %%
new_data =ndf.dropna (axis = 0, how ='any')
new_data
# Out:
#     math score  reading score  writing score  club join year  placement offer  \
# 0           70      78.000000             80            2021                2
# 1           73      62.000000             70            2022                2
# 2           75      60.000000             79            2022                1
# 3           80      70.000000             61            2022                3
# 4           60      67.000000             79            2024                3
# 5           80      68.714286             71            2020                1
# 6           62      67.000000             79            2023                2
# 7           63      69.000000             74            2018                2
# 8           62      71.000000             71            2018                3
# 9           76      73.000000             73            2024                2
# 10          65      66.000000             73            2019                3
# 11          70      75.000000             79            2020                1
# 12          75      67.000000             77            2024                2
# 13          80      61.000000             65            2019                3
# 14          62      66.000000             69            2019                1
# 15          74      80.000000             79            2018                1
# 16          72      79.000000             77            2022                3
# 17          70      62.000000             78            2024                1
# 18          72      70.000000             74            2023                2
# 19          64      68.000000             71            2019                1
# 20          64      62.000000             69            2018                3
# 21          68      63.000000             65            2023                3
# 22          60      67.000000             75            2024                3
# 23          73      65.000000             76            2021                2
# 24          72      79.000000             63            2018                3
# 25          76      64.000000             72            2021                1
# 26          75      79.000000             62            2019                1
# 27          79      60.000000             66            2019                2
# 28          80      74.000000             73            2022                2
#
#     gender
# 0     male
# 1   female
# 2   female
# 3     male
# 4     male
# 5   female
# 6   female
# 7   female
# 8     male
# 9     male
# 10  female
# 11  female
# 12  female
# 13  female
# 14    male
# 15  female
# 16  female
# 17  female
# 18  female
# 19  female
# 20    male
# 21  female
# 22  female
# 23  female
# 24    male
# 25    male
# 26  female
# 27  female
# 28  female

# %%
col =['reading score', 'reading score', 'writing score', 'placement offer']
df.boxplot(col)
# Out:
# <Axes: >

# %%
print(np.where(df['reading score']>90))
print(np.where(df['writing score']>90))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
fig, ax =plt.subplots(figsize = (18,10))
ax.scatter(df['reading score'], df['writing score'])
plt.show()
ax.set_xlabel('(Proportion non-retail business acres)/(town)')
ax.set_ylabel('(Full-value property-tax rate)/($10,000)')
# Out:
# Text(4.444444444444452, 0.5, '(Full-value property-tax rate)/($10,000)')

# %%
print(np.where((df['reading score']<50) & (df['writing score']>1)))
print(np.where((df['reading score']>85) & (df['writing score']<3)))
# Out:
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
z = np.abs(stats.zscore(df['reading score']))

# %%
print(z)
# Out:
# 0     1.530336e+00
# 1     1.106551e+00
# 2     1.436161e+00
# 3     2.118927e-01
# 4     2.825236e-01
# 5     2.342026e-15
# 6     2.825236e-01
# 7     4.708726e-02
# 8     3.766981e-01
# 9     7.063089e-01
# 10    4.473290e-01
# 11    1.035920e+00
# 12    2.825236e-01
# 13    1.271356e+00
# 14    4.473290e-01
# 15    1.859947e+00
# 16    1.695141e+00
# 17    1.106551e+00
# 18    2.118927e-01
# 19    1.177182e-01
# 20    1.106551e+00
# 21    9.417452e-01
# 22    2.825236e-01
# 23    6.121344e-01
# 24    1.695141e+00
# 25    7.769398e-01
# 26    1.695141e+00
# 27    1.436161e+00
# 28    8.711143e-01
# Name: reading score, dtype: float64

# %%
threshold = 0.18

# %%
sample_outliers = np.where(z <threshold)

# %%
sample_outliers
# Out:
# (array([ 5,  7, 19], dtype=int64),)

# %%
sorted_rscore= sorted(df['reading score'])

# %%
sorted_rscore
# Out:
# [60.0,
#  60.0,
#  61.0,
#  62.0,
#  62.0,
#  62.0,
#  63.0,
#  64.0,
#  65.0,
#  66.0,
#  66.0,
#  67.0,
#  67.0,
#  67.0,
#  67.0,
#  68.0,
#  68.71428571428571,
#  69.0,
#  70.0,
#  70.0,
#  71.0,
#  73.0,
#  74.0,
#  75.0,
#  78.0,
#  79.0,
#  79.0,
#  79.0,
#  80.0]

# %%
q1 = np.percentile(sorted_rscore, 25)
q3 = np.percentile(sorted_rscore, 75)
print(q1,q3)
# Out:
# 64.0 73.0

# %%
IQR = q3-q1

# %%
lwr_bound = q1-(1.5*IQR)
upr_bound = q3+(1.5*IQR)
print(lwr_bound, upr_bound)
# Out:
# 50.5 86.5

# %%
r_outliers = []
for i in sorted_rscore:
    if (i<lwr_bound or i>upr_bound):
        r_outliers.append(i)
        print(r_outliers)

# %%
new_df=df
for i in sample_outliers:new_df.drop(i,inplace=True)
new_df
# Out:
#     math score  reading score  writing score  club join year  placement offer  \
# 0           70           78.0             80            2021                2
# 1           73           62.0             70            2022                2
# 2           75           60.0             79            2022                1
# 3           80           70.0             61            2022                3
# 4           60           67.0             79            2024                3
# 6           62           67.0             79            2023                2
# 8           62           71.0             71            2018                3
# 9           76           73.0             73            2024                2
# 10          65           66.0             73            2019                3
# 11          70           75.0             79            2020                1
# 12          75           67.0             77            2024                2
# 13          80           61.0             65            2019                3
# 14          62           66.0             69            2019                1
# 15          74           80.0             79            2018                1
# 16          72           79.0             77            2022                3
# 17          70           62.0             78            2024                1
# 18          72           70.0             74            2023                2
# 20          64           62.0             69            2018                3
# 21          68           63.0             65            2023                3
# 22          60           67.0             75            2024                3
# 23          73           65.0             76            2021                2
# 24          72           79.0             63            2018                3
# 25          76           64.0             72            2021                1
# 26          75           79.0             62            2019                1
# 27          79           60.0             66            2019                2
# 28          80           74.0             73            2022                2
#
#     gender
# 0     male
# 1   female
# 2   female
# 3     male
# 4     male
# 6   female
# 8     male
# 9     male
# 10  female
# 11  female
# 12  female
# 13  female
# 14    male
# 15  female
# 16  female
# 17  female
# 18  female
# 20    male
# 21  female
# 22  female
# 23  female
# 24    male
# 25    male
# 26  female
# 27  female
# 28  female

# %%
df=pd.read_excel("C:/Users/LENOVO/Desktop/students.csv.xlsx")

# %%
df_stud=df
ninetieth_percentile = np.percentile(df_stud['reading score'], 90)
b = np.where(df_stud['reading score']>ninetieth_percentile,
ninetieth_percentile, df_stud['reading score'])
print("New array:",b)
# Out:
# New array: [78. 62. 60. 70. 67. nan 67. 69. 71. 73. 66. 75. 67. 61. 66. 80. 79. 62.
#  70. 68. 62. 63. 67. 65. 79. 64. 79. 60. 74.]

# %%
df_stud.insert(1,"m score",b,True)
df_stud
# Out:
#     math score  m score  reading score  writing score  club join year  \
# 0           70     78.0           78.0             80            2021
# 1           73     62.0           62.0             70            2022
# 2           75     60.0           60.0             79            2022
# 3           80     70.0           70.0             61            2022
# 4           60     67.0           67.0             79            2024
# 5           80      NaN            NaN             71            2020
# 6           62     67.0           67.0             79            2023
# 7           63     69.0           69.0             74            2018
# 8           62     71.0           71.0             71            2018
# 9           76     73.0           73.0             73            2024
# 10          65     66.0           66.0             73            2019
# 11          70     75.0           75.0             79            2020
# 12          75     67.0           67.0             77            2024
# 13          80     61.0           61.0             65            2019
# 14          62     66.0           66.0             69            2019
# 15          74     80.0           80.0             79            2018
# 16          72     79.0           79.0             77            2022
# 17          70     62.0           62.0             78            2024
# 18          72     70.0           70.0             74            2023
# 19          64     68.0           68.0             71            2019
# 20          64     62.0           62.0             69            2018
# 21          68     63.0           63.0             65            2023
# 22          60     67.0           67.0             75            2024
# 23          73     65.0           65.0             76            2021
# 24          72     79.0           79.0             63            2018
# 25          76     64.0           64.0             72            2021
# 26          75     79.0           79.0             62            2019
# 27          79     60.0           60.0             66            2019
# 28          80     74.0           74.0             73            2022
#
#     placement offer  gender
# 0                 2    male
# 1                 2  female
# 2                 1  female
# 3                 3    male
# 4                 3    male
# 5                 1  female
# 6                 2  female
# 7                 2  female
# 8                 3    male
# 9                 2    male
# 10                3  female
# 11                1  female
# 12                2  female
# 13                3  female
# 14                1    male
# 15                1  female
# 16                3  female
# 17                1  female
# 18                2  female
# 19                1  female
# 20                3    male
# 21                3  female
# 22                3  female
# 23                2  female
# 24                3    male
# 25                1    male
# 26                1  female
# 27                2  female
# 28                2  female

# %%
col = ['reading score']

df.boxplot(col)
# Out:
# <Axes: >

# %%
median=np.median(sorted_rscore)
median
# Out:
# 67.0

# %%
refined_df=df
refined_df['reading score'] = np.where(refined_df['reading score'] >upr_bound, median,refined_df['reading score'])

# %%
df
# Out:
#     math score  reading score  writing score  club join year  placement offer  \
# 0           70           78.0             80            2021                2
# 1           73           62.0             70            2022                2
# 2           75           60.0             79            2022                1
# 3           80           70.0             61            2022                3
# 4           60           67.0             79            2024                3
# 5           80            NaN             71            2020                1
# 6           62           67.0             79            2023                2
# 7           63           69.0             74            2018                2
# 8           62           71.0             71            2018                3
# 9           76           73.0             73            2024                2
# 10          65           66.0             73            2019                3
# 11          70           75.0             79            2020                1
# 12          75           67.0             77            2024                2
# 13          80           61.0             65            2019                3
# 14          62           66.0             69            2019                1
# 15          74           80.0             79            2018                1
# 16          72           79.0             77            2022                3
# 17          70           62.0             78            2024                1
# 18          72           70.0             74            2023                2
# 19          64           68.0             71            2019                1
# 20          64           62.0             69            2018                3
# 21          68           63.0             65            2023                3
# 22          60           67.0             75            2024                3
# 23          73           65.0             76            2021                2
# 24          72           79.0             63            2018                3
# 25          76           64.0             72            2021                1
# 26          75           79.0             62            2019                1
# 27          79           60.0             66            2019                2
# 28          80           74.0             73            2022                2
#
#     gender
# 0     male
# 1   female
# 2   female
# 3     male
# 4     male
# 5   female
# 6   female
# 7   female
# 8     male
# 9     male
# 10  female
# 11  female
# 12  female
# 13  female
# 14    male
# 15  female
# 16  female
# 17  female
# 18  female
# 19  female
# 20    male
# 21  female
# 22  female
# 23  female
# 24    male
# 25    male
# 26  female
# 27  female
# 28  female

# %%
refined_df['reading score'] = np.where(refined_df['reading score'] <lwr_bound, median,refined_df['reading score'])

# %%
df
# Out:
#     math score  reading score  writing score  club join year  placement offer  \
# 0           70           78.0             80            2021                2
# 1           73           62.0             70            2022                2
# 2           75           60.0             79            2022                1
# 3           80           70.0             61            2022                3
# 4           60           67.0             79            2024                3
# 5           80            NaN             71            2020                1
# 6           62           67.0             79            2023                2
# 7           63           69.0             74            2018                2
# 8           62           71.0             71            2018                3
# 9           76           73.0             73            2024                2
# 10          65           66.0             73            2019                3
# 11          70           75.0             79            2020                1
# 12          75           67.0             77            2024                2
# 13          80           61.0             65            2019                3
# 14          62           66.0             69            2019                1
# 15          74           80.0             79            2018                1
# 16          72           79.0             77            2022                3
# 17          70           62.0             78            2024                1
# 18          72           70.0             74            2023                2
# 19          64           68.0             71            2019                1
# 20          64           62.0             69            2018                3
# 21          68           63.0             65            2023                3
# 22          60           67.0             75            2024                3
# 23          73           65.0             76            2021                2
# 24          72           79.0             63            2018                3
# 25          76           64.0             72            2021                1
# 26          75           79.0             62            2019                1
# 27          79           60.0             66            2019                2
# 28          80           74.0             73            2022                2
#
#     gender
# 0     male
# 1   female
# 2   female
# 3     male
# 4     male
# 5   female
# 6   female
# 7   female
# 8     male
# 9     male
# 10  female
# 11  female
# 12  female
# 13  female
# 14    male
# 15  female
# 16  female
# 17  female
# 18  female
# 19  female
# 20    male
# 21  female
# 22  female
# 23  female
# 24    male
# 25    male
# 26  female
# 27  female
# 28  female

# %%
col = ['reading score']
refined_df.boxplot(col)
# Out:
# <Axes: >

# %%
df
# Out:
#     math score  reading score  writing score  club join year  placement offer  \
# 0           70           78.0             80            2021                2
# 1           73           62.0             70            2022                2
# 2           75           60.0             79            2022                1
# 3           80           70.0             61            2022                3
# 4           60           67.0             79            2024                3
# 5           80            NaN             71            2020                1
# 6           62           67.0             79            2023                2
# 7           63           69.0             74            2018                2
# 8           62           71.0             71            2018                3
# 9           76           73.0             73            2024                2
# 10          65           66.0             73            2019                3
# 11          70           75.0             79            2020                1
# 12          75           67.0             77            2024                2
# 13          80           61.0             65            2019                3
# 14          62           66.0             69            2019                1
# 15          74           80.0             79            2018                1
# 16          72           79.0             77            2022                3
# 17          70           62.0             78            2024                1
# 18          72           70.0             74            2023                2
# 19          64           68.0             71            2019                1
# 20          64           62.0             69            2018                3
# 21          68           63.0             65            2023                3
# 22          60           67.0             75            2024                3
# 23          73           65.0             76            2021                2
# 24          72           79.0             63            2018                3
# 25          76           64.0             72            2021                1
# 26          75           79.0             62            2019                1
# 27          79           60.0             66            2019                2
# 28          80           74.0             73            2022                2
#
#     gender
# 0     male
# 1   female
# 2   female
# 3     male
# 4     male
# 5   female
# 6   female
# 7   female
# 8     male
# 9     male
# 10  female
# 11  female
# 12  female
# 13  female
# 14    male
# 15  female
# 16  female
# 17  female
# 18  female
# 19  female
# 20    male
# 21  female
# 22  female
# 23  female
# 24    male
# 25    male
# 26  female
# 27  female
# 28  female

# %%
import matplotlib.pyplot as plt
new_df['reading score'].plot(kind ='hist')
df['log_math'] = np.log10(df['reading score'])
